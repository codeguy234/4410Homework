# %% [markdown]
# <a href="https://colab.research.google.com/github/codeguy234/4410Homework/blob/main/WK7v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import requests
import matplotlib.pyplot as plt
from collections import Counter
import string
from textblob import TextBlob

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')

# url hamlet text
target_url = 'http://www.gutenberg.org/files/2265/2265.txt'
response = requests.get(target_url)
data = response.text

blob = TextBlob(data)

# stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word not in stop_words and len(word) > 2]

# count / common words
word_freq = Counter(filtered_words)
top_words = word_freq.most_common(20)

# extract words for plotting
words_list = [word[0] for word in top_words]
freq_list = [word[1] for word in top_words]

plt.figure(figsize=(12, 8))
plt.bar(words_list, freq_list, color='blue')
plt.xlabel('Words')
plt.ylabel('Times Used')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
